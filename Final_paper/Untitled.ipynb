# %%
import force
from pathlib import Path
import matplotlib.pyplot as plt
import pandas as pd
import os
import glob
import numpy as np
import time
import pickle
from statistics import mean

# %%
force.plotting_Normal_Force('./Data/force/TCP/OFF_Z','OFF_Z',False,['80mm','60mm','40mm'],'Friction coefficient',['80mm','60mm','40mm'],'red')
force.plotting_Normal_Force('./Data/force/TCP/OFF_Y','OFF_Y',False,['-20','-10mm','0mm'],'Friction coefficient',['-20','-10mm','0mm'],'orange')
force.plotting_Normal_Force('./Data/force/Object/Contact_area','Pressure',False,['0.4bar','0.8bar','1.2bar'],'Friction coefficient',['Large','med','small'],'blue')
force.plotting_Normal_Force('./Data/force/Pressure/Frictiontape_Different_pressure','Pressure',False,['0.4bar','0.8bar','1.2bar'],'Friction coefficient',['0.8bar','1.2bar','0.4bar'],'green')
force.plotting_Normal_Force('./Data/force/Object/Friction_tape','Pressure',False,['0.4bar','0.8bar','1.2bar'],'Friction coefficient',['0.8bar','1.2bar','0.4bar'],'lime')
force.plotting_Normal_Force('./Data/force/Multi_finger/TWO_finger_Right_Left','Pressure',False,['0.4bar','0.8bar','1.2bar'],'Friction coefficient',['both','right','left'],'gray')
